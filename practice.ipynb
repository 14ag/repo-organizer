# %%
import os
import re
import json
import sys

# %%
def create_multiplier(factor):
    """Returns a function that multiplies its input by the given factor."""
    def multiplier(x):
        return x * factor
    return multiplier

# Create specific multiplier functions
double = create_multiplier(2)
triple = create_multiplier(3)

# Use the created functions
print(double(5))  # Output: 10
print(triple(5))  # Output: 15

# %%
def main(str0):
    line0=str0

    def printSwitch():
        #returns true to allow main to send out to a new readme
        start_regex=r"^\d{1,2}:##\s" #title pattern
        end_regex=r"<br>"
        file_regex=r"#\s\d{1,2}"
        match_start=re.search(start_regex, line0)
        match_end=re.search(end_regex, line0)
        match_file=re.search(file_regex, line0)

        def getBranchName():
            #returns the title of the new branch name and next readme

            regex1=r'(?<=").*(?=")' #selects all that comes btn quotes
            branch_name=re.search(regex1,line0).group(0)
            branch_name=branch_name.replace(" ","-").lower()
            return branch_name
        
        def getFileName():
            #returns file name associated with the index

            regex1=r"(?<=#\s)\d{1,2}"
            file_num=re.search(regex1,line0).group(0)

            with open(r"file_list.json", "r") as test0:
                file_list=json.loads(test0.read())

            file_name="".join(file_list[file_num])
            return file_name
        
        if match_start:
            return True, getBranchName()
        elif match_end:
            return False, 0
        elif match_file:
            return False, getFileName()
        else:
            return True, 0
        
    return " ".join(str(i) for i in printSwitch())

print(main('60:# 10'))
print(main('60:# 9'))
print(main('60:## The Challenge: The "Dinner Bill Splitter"'))
print(main('60:hello'))
print(main('60:<br>'))
# Out:
# False 10_palindrome_checker.py
# False 9_lone_survivor.py
# True dinner-bill-splitter
# True 0
# False 0

# %%
x="Dinner Bill Splitter"
print(x.replace(" ","-").lower())
# Out:
# dinner-bill-splitter

# %%
x=(5, 'The "Dinner Bill Splitter"')
y=" ".join(str(item) for item in x)
print(y)

# %%
working_directory=r"..\test"
print(working_directory)
print(os.chdir(working_directory))
print(os.getcwd())
type(os.listdir())
os.listdir()

# %%
file_list_json={}
working_directory=r"..\test"
os.chdir(working_directory)
file_list=os.listdir()

for file in file_list:
    file_list_json[file[:2].strip("_")]=file

print(file_list_json)

# %%
with open(r"test\test.txt", "r") as test0:
    content=test0.read()


print(content)
print("done")
# Out:
# vanrvrevnrevre
# rva evrv;apcom
# xxmbbc,vbxvbcx,
# done
