# %%
import os
import re
import json
import sys

# %%
def create_multiplier(factor):
    """Returns a function that multiplies its input by the given factor."""
    def multiplier(x):
        return x * factor
    return multiplier

# Create specific multiplier functions
double = create_multiplier(2)
triple = create_multiplier(3)

# Use the created functions
print(double(5))  # Output: 10
print(triple(5))  # Output: 15

# %%
def main(str0):
    line0=str0

    def printSwitch():
        #returns true to allow main to send out to a new readme
        
        start_regex=r"^##\s" #title pattern
        end_regex=r"<br>"
        file_regex=r"(?<=^#\s)\d{1,}"
        #file_regex=r"()"
        match_start=re.search(start_regex, line0)
        match_end=re.search(end_regex, line0)
        match_file=re.search(file_regex, line0)

        def getBranchName():
            #returns the title of the new branch name and next readme

            regex1=r"(?<=:\s).*" #selects all that comes after colon and a wspace
            branch_name=re.search(regex1,line0).group(0)
            return branch_name
        
        def getFileName():
            with open(r"test\test.txt", "r") as test0:
               # file_list=json.loads(test0.read())
                print(test0.read())
               # print(file_list)


                #
                # to json
                #             
            n=match_file.group(0)
            #file_name="".join(file_list[n])
            file_name=""
            #
            #
            #
            #
            #
            #
            #
            return file_name
        
        if match_start:
            return True, getBranchName()
        elif match_end:
            return False, 0
        elif match_file:
            return False, getFileName()
        else:
            return True, 1
    
    return " ".join(str(i) for i in printSwitch())

print(main('## The Challenge: The "Dinner Bill Splitter"'))
print(main('hello'))
print(main('<br>'))
print(main('# 9'))
print(main('# 10'))
# Out:
# True The "Dinner Bill Splitter"
# True 1
# False 0
# {'10': '10_palindrome_checker.py', '11': '11_fizzbuzz_array.py', '12': '12_target_sum.py', '13': '13_duplicate_finder.py', '22': '22_25%_appearance.py', '8': '8_robust_calculator.py', '9': '9_lone_survivor.py', 'fi': 'file_list.json', 'te': 'test.txt'}
# False
# {'10': '10_palindrome_checker.py', '11': '11_fizzbuzz_array.py', '12': '12_target_sum.py', '13': '13_duplicate_finder.py', '22': '22_25%_appearance.py', '8': '8_robust_calculator.py', '9': '9_lone_survivor.py', 'fi': 'file_list.json', 'te': 'test.txt'}
# False

# %%
x=(5, 'The "Dinner Bill Splitter"')
y=" ".join(str(item) for item in x)
print(y)

# %%
working_directory=r"..\test"
print(working_directory)
print(os.chdir(working_directory))
print(os.getcwd())
type(os.listdir())
os.listdir()

# %%
file_list_json={}
working_directory=r"..\test"
os.chdir(working_directory)
file_list=os.listdir()

for file in file_list:
    file_list_json[file[:2].strip("_")]=file

print(file_list_json)

# %%
with open(r"test\test.txt", "r") as test0:
    content=test0.read()


print(content)
print("done")
# Out:
# vanrvrevnrevre
# rva evrv;apcom
# xxmbbc,vbxvbcx,
# done
